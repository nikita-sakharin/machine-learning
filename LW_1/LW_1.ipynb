# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
im = cv2.imread("big.jpg")
plt.imshow(im)

# %% [markdown]
# ## Какого размера изображение? Ответ - произведение ширины на высоту.

# %%
im.shape
# Out:
# (375, 500, 3)

# %%
im.shape[0] * im.shape[1]
# Out:
# 187500

# %% [markdown]
# ## Найдите среднее значению по каждому из каналов. Ответ - среднее в 3 канале, округлить до целого.

# %%
mean = im.mean(axis=(0,1))
mean
# Out:
# array([ 49.91059733,  92.14002667, 128.69120533])

# %%
np.round(mean, 0)[2]
# Out:
# 129.0

# %% [markdown]
# ## Посчитайте разброс (среднеквадратичное отклонение) значений по каждому из каналов.Ответ - разброс в 1 канале, округлить до целого.

# %%
std = im.std(axis=(0,1))
std
# Out:
# array([38.29606242, 62.76430657, 77.48906153])

# %%
np.round(std, 0)[0]
# Out:
# 38.0

# %% [markdown]
# ## Поменяйте каналы исходного изображения в обратном порядке, какое число стоит на позиции [0,345,0].

# %%
np.flip(im, 2)[0, 345, 0]
# Out:
# 192

# %% [markdown]
# ## Сколько столбцов, в которых есть хоть одно значение 7?

# %%
np.random.seed(7964)
A = np.random.randint(0, 8, size=(500, 500)) 
A
# Out:
# array([[5, 6, 2, ..., 1, 4, 2],
#        [6, 3, 4, ..., 2, 3, 5],
#        [1, 2, 5, ..., 6, 3, 1],
#        ...,
#        [1, 3, 4, ..., 4, 7, 0],
#        [1, 3, 7, ..., 2, 4, 4],
#        [5, 7, 6, ..., 7, 4, 2]])

# %%
eq_7 = (A == 7)
eq_7
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False,  True, False],
#        [False, False,  True, ..., False, False, False],
#        [False,  True, False, ...,  True, False, False]])

# %%
any_in_col = eq_7.any(axis=0)
any_in_col
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
any_in_col.sum()
# Out:
# 500

# %% [markdown]
# ## Найдите индексы значений, которые меньше 4. Ответ - сумма сумм индексов строк и столбцов между собой.

# %%
indices = np.argwhere(A < 4)
indices
# Out:
# array([[  0,   2],
#        [  0,   5],
#        [  0,   6],
#        ...,
#        [499, 493],
#        [499, 495],
#        [499, 499]], dtype=int64)

# %%
indices_sum = indices.sum(axis=0)
indices_sum
# Out:
# array([31222690, 31160862], dtype=int64)

# %%
indices_sum.sum()
# Out:
# 62383552

# %% [markdown]
# ## Найдите индексы значений, которые меньше 4 и не меньше 2. Ответ - сумма сумм индексов строк и столбцов между собой.

# %%
indices = np.argwhere((2 <= A) & (A < 4))
indices
# Out:
# array([[  0,   2],
#        [  0,   6],
#        [  0,   7],
#        ...,
#        [499, 489],
#        [499, 493],
#        [499, 499]], dtype=int64)

# %%
indices_sum = indices.sum(axis=0)
indices_sum
# Out:
# array([15582739, 15557089], dtype=int64)

# %%
indices_sum.sum()
# Out:
# 31139828

# %% [markdown]
# ## Просуммировать все значения по индексам значений из предыдущего задания.

# %%
values = A[(2 <= A) & (A < 4)]
values
# Out:
# array([2, 2, 3, ..., 2, 3, 2])

# %%
values.sum()
# Out:
# 156096

# %% [markdown]
# ## Найдите максимальное значение в каждом столбце массива. Ответ - сумма значений.

# %%
max_in_col = A.max(axis=0)
max_in_col
# Out:
# array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7])

# %%
max_in_col.sum()
# Out:
# 3500

# %% [markdown]
# ## Найти скалярное произведение массива A и x. Ответ - сумма значений.

# %%
x = np.arange(1, 501, 1)
A.dot(x).sum()
# Out:
# 218833635

# %% [markdown]
# ## Умножьте массив A на массив w транспонированный. Ответ - сумма значений.

# %%
np.random.seed(33)
w = np.random.randint(0, 8, size=(5, 500))
w
# Out:
# array([[4, 7, 0, ..., 5, 1, 3],
#        [1, 6, 2, ..., 0, 6, 5],
#        [6, 4, 5, ..., 0, 3, 7],
#        [6, 6, 2, ..., 7, 4, 6],
#        [0, 7, 6, ..., 3, 1, 3]])

# %%
A.dot(w.transpose()).sum()
# Out:
# 15215957

# %% [markdown]
# ## Умножьте массив A на массив w поэлементно. Ответ - сумма значений.

# %%
a_w_multiply = np.multiply(np.split(A, A.shape[0] // w.shape[0]), w).reshape(A.shape)
a_w_multiply
# Out:
# array([[20, 42,  0, ...,  5,  4,  6],
#        [ 6, 18,  8, ...,  0, 18, 25],
#        [ 6,  8, 25, ...,  0,  9,  7],
#        ...,
#        [ 6, 12, 20, ...,  0, 21,  0],
#        [ 6, 18, 14, ..., 14, 16, 24],
#        [ 0, 49, 36, ..., 21,  4,  6]])

# %%
a_w_multiply.sum()
# Out:
# 3045726
